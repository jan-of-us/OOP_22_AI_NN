# %% [markdown]
# This notebook shows the implementation of the classes in this repository

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from AI_Classification.NN_Classification import NN_Classification
from AI_Classification.Classification_Data import Classification_Data
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("Data/divorce.csv", delimiter=";")
data_obj = Classification_Data(data=data)
classifier = NN_Classification(data_obj=data_obj)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 0s 39ms/step - loss: 0.6071 - accuracy: 0.6296 - val_loss: 0.3913 - val_accuracy: 0.8214
# Epoch 2/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3444 - accuracy: 0.8426 - val_loss: 0.3175 - val_accuracy: 0.8571
# Epoch 3/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2488 - accuracy: 0.9259 - val_loss: 0.2842 - val_accuracy: 0.8571
# Epoch 4/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1444 - accuracy: 0.9815 - val_loss: 0.2612 - val_accuracy: 0.8929
# Epoch 5/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1257 - accuracy: 0.9722 - val_loss: 0.2464 - val_accuracy: 0.9286
# Epoch 6/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0724 - accuracy: 0.9907 - val_loss: 0.2231 - val_accuracy: 0.9286
# Epoch 7/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0585 - accuracy: 0.9815 - val_loss: 0.2237 - val_accuracy: 0.9286
# Epoch 8/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0490 - accuracy: 0.9907 - val_loss: 0.2348 - val_accuracy: 0.9286
# Epoch 9/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.2546 - val_accuracy: 0.9286
# Epoch 10/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9286
# Model created
# 2/2 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 500us/step
# 5/5 [==============================] - 0s 500us/step

# %%
from AI_Classification.RF_Classification import RF_Classification

# %%
rf_obj = Classification_Data(data=data, trees=300)
forest = RF_Classification(rf_obj)
# Out:
# Model created

# %%
import pandas as pd
from AI_Regression.Regression_Data import Regression_Data
from AI_Regression.RF_Regression import RF_Regression
from AI_Regression.NN_Regression import NN_Regression

# %%
reg_data = pd.read_csv("Data/energydata_complete.csv")

rf_reg_obj = Regression_Data(data=reg_data, y_label="Appliances", n_values=50, trees=100, scale=True)
reg_forest = RF_Regression(rf_reg_obj)
# Out:
# Column converted: date
# Model created

# %%
print(rf_reg_obj.result_string)
# Out:
# The following column was converted: 'date'
#
# The regressors R2_Score is 0.53.
#
# The mean abs. error is 0.030.
#
# The mean squared error is 0.004.

# %%
nn_reg_obj = Regression_Data(data=reg_data, y_label="Appliances")
nn_reg = NN_Regression(nn_reg_obj)
# Out:
# Column converted: date
# Epoch 1/10
# 395/395 [==============================] - 1s 1ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 2/10
# 395/395 [==============================] - 0s 868us/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 3/10
# 395/395 [==============================] - 0s 858us/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 4/10
# 395/395 [==============================] - 0s 862us/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 5/10
# 395/395 [==============================] - 0s 845us/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 6/10
# 395/395 [==============================] - 0s 853us/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 7/10
# 395/395 [==============================] - 0s 848us/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 8/10
# 395/395 [==============================] - 0s 848us/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 9/10
# 395/395 [==============================] - 0s 873us/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 10/10
# 395/395 [==============================] - 0s 858us/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0085 - val_mse: 0.0085
# 124/124 [==============================] - 0s 569us/step - loss: 0.0076 - mse: 0.0076
# Model created
# 124/124 [==============================] - 0s 496us/step
# 494/494 [==============================] - 0s 501us/step
