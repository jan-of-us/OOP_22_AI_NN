# %% [markdown]
# This notebook shows the implementation of the classes in this repository

# %%
from AI_Classification.NN_Classification import NN_Classification
from AI_Classification.Classification_Data import Classification_Data
import pandas as pd
# %matplotlib inline
# Out:
# c:\Users\jansc\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\jansc\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\jansc\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data = pd.read_csv("Data/divorce.csv", delimiter=";")
data_obj = Classification_Data(data=data)
classifier = NN_Classification(data_obj=data_obj)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 0s 39ms/step - loss: 1.4924 - accuracy: 0.3981 - val_loss: 0.5612 - val_accuracy: 0.5357
# Epoch 2/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5101 - accuracy: 0.6852 - val_loss: 0.5466 - val_accuracy: 0.6071
# Epoch 3/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4171 - accuracy: 0.7685 - val_loss: 0.4701 - val_accuracy: 0.7500
# Epoch 4/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3901 - accuracy: 0.7870 - val_loss: 0.3717 - val_accuracy: 0.8571
# Epoch 5/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2749 - accuracy: 0.8704 - val_loss: 0.2809 - val_accuracy: 0.8929
# Epoch 6/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2152 - accuracy: 0.9537 - val_loss: 0.2128 - val_accuracy: 0.9643
# Epoch 7/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1746 - accuracy: 0.9444 - val_loss: 0.1651 - val_accuracy: 0.9643
# ...

# %%
stringlist = []
classifier.model.summary(print_fn=lambda x: stringlist.append(x))
short_model_summary = "\n".join(stringlist)

# %%
print(short_model_summary)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                3520
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# ...
# Total params: 7,810
# Trainable params: 7,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
from AI_Classification.RF_Classification import RF_Classification

# %%
rf_obj = Classification_Data(data=data, trees=300)
forest = RF_Classification(rf_obj)
# Out:
# Model created

# %%
import pandas as pd
from AI_Regression.Regression_Data import Regression_Data
from AI_Regression.RF_Regression import RF_Regression
from AI_Regression.NN_Regression import NN_Regression

# %%
reg_data = pd.read_csv("Data/energydata_complete.csv")

rf_reg_obj = Regression_Data(data=reg_data, y_label="Appliances", n_values=50, trees=100, scale=True)
reg_forest = RF_Regression(rf_reg_obj)
# Out:
# Column converted: date
# c:\Users\jansc\Projects\OOP_22_AI_NN\AI_Regression\RF_Regression.py:57: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(self.x_train, self.y_train)
# Model created

# %%
print(rf_reg_obj.result_string)
# Out:
# The following column was converted: 'date'
#
# The regressors R2_Score is 0.53.
#
# The mean abs. error is 0.032.
#
# The mean squared error is 0.004.

# %%
nn_reg_obj = Regression_Data(data=reg_data, y_label="Appliances")
nn_reg = NN_Regression(nn_reg_obj)
# Out:
# Column converted: date
# Epoch 1/10
# 395/395 [==============================] - 1s 1ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 2/10
# 395/395 [==============================] - 0s 860us/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 3/10
# 395/395 [==============================] - 0s 862us/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 4/10
# 395/395 [==============================] - 0s 858us/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 5/10
# 395/395 [==============================] - 0s 853us/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 6/10
# 395/395 [==============================] - 0s 855us/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 7/10
# 395/395 [==============================] - 0s 868us/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0077 - val_mse: 0.0077
# ...
